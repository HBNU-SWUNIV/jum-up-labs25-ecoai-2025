# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = preprocessing.MinMaxScaler()

num_cols = ['meter_reading'] #,"hour" 
scaler = MinMaxScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
import numpy as np

def sliding_windows_with_labels(df, window_size):
    labels = df["anomaly"].values
    data = df.drop(["anomaly"], axis=1).values

    X_windows = []
    y_labels = []

    for i in range(len(df) - window_size + 1):
        window = data[i:i+window_size]
        window_label = labels[i:i+window_size]

        X_windows.append(window)
        y_labels.append(float(any(window_label)))  # 윈도우에 이상치 하나라도 있으면 1

    return np.array(X_windows), np.array(y_labels)

# %%
window_size = 24
X_windows, y_labels = sliding_windows_with_labels(df, window_size)

print("X_windows shape:", X_windows.shape)  # (윈도우 개수, window_size, 특성 수)
print("y_labels shape:", y_labels.shape)    # (윈도우 개수,)
# Out:
# X_windows shape: (8735, 24, 1)
# y_labels shape: (8735,)

# %%
from sklearn.utils import shuffle

X_shuffled, y_shuffled = shuffle(X_windows, y_labels, random_state=42)

# %%
import numpy as np

# 1. 이상치 여부에 따라 정렬 (label==0 먼저, label==1 나중)
normal_mask = y_shuffled == 0
anomaly_mask = y_shuffled == 1

X_normal = X_shuffled[normal_mask]
y_normal = y_shuffled[normal_mask]

X_anomaly = X_shuffled[anomaly_mask]
y_anomaly = y_shuffled[anomaly_mask]

# 다시 합치기: 정상 → 이상 순서
X_sorted = np.concatenate([X_normal, X_anomaly], axis=0)
y_sorted = np.concatenate([y_normal, y_anomaly], axis=0)

# 2. 6:2:2로 분할
total = len(X_sorted)
n_train = int(total * 0.6)
n_val = int(total * 0.2)

X_train = X_sorted[:n_train]
y_train = y_sorted[:n_train]

X_val = X_sorted[n_train:n_train + n_val]
y_val = y_sorted[n_train:n_train + n_val]

X_test = X_sorted[n_train + n_val:]
y_test = y_sorted[n_train + n_val:]

# %%
print("X_train shape:", X_train.shape)
print("X_val shape:", X_val.shape)
print("X_test shape:", X_test.shape)

print("y_train 이상치 비율:", y_train.mean())
print("y_val 이상치 비율:", y_val.mean())
print("y_test 이상치 비율:", y_test.mean())

if y_val.sum() == 0:
    print("✅ val에는 이상치가 없습니다.")
else:
    print("❌ val에 이상치가 있습니다.")
# Out:
# X_train shape: (5241, 24, 1)
# X_val shape: (1747, 24, 1)
# X_test shape: (1747, 24, 1)
# y_train 이상치 비율: 0.0
# y_val 이상치 비율: 0.0
# y_test 이상치 비율: 0.6977676016027475
# ✅ val에는 이상치가 없습니다.

# %%
windows_normal_train = X_train        # 정상 train 윈도우
windows_normal_val = X_val            # 정상 validation 윈도우
windows_attack = X_test               # test: 정상 + 이상 포함
labels = y_test                       # test 윈도우별 이상 여부

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.utils.data as data_utils
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
import random
from sklearn.metrics import f1_score, recall_score, precision_score


from utils_f1 import *
from usad_lead_f1 import *


random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
import torch.utils.data as data_utils

BATCH_SIZE = 64
N_EPOCHS = 1000
hidden_size = 0.5


w_size=windows_normal_train.shape[1]*windows_normal_train.shape[2]
z_size= int(windows_normal_train.shape[1]*hidden_size)

# windows_normal_train = windows_normal[:int(np.floor(.8 *  windows_normal.shape[0]))]
# windows_normal_val = windows_normal[int(np.floor(.8 *  windows_normal.shape[0])):int(np.floor(windows_normal.shape[0]))]

train_loader = torch.utils.data.DataLoader(data_utils.TensorDataset(
    torch.from_numpy(windows_normal_train).float().view(([windows_normal_train.shape[0],w_size]))
) , batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

val_loader = torch.utils.data.DataLoader(data_utils.TensorDataset(
    torch.from_numpy(windows_normal_val).float().view(([windows_normal_val.shape[0],w_size]))
) , batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

test_loader = torch.utils.data.DataLoader(data_utils.TensorDataset(
    torch.from_numpy(windows_attack).float().view(([windows_attack.shape[0],w_size]))
) , batch_size=BATCH_SIZE, shuffle=False, num_workers=0)



model = UsadModel(w_size, z_size)
model = to_device(model, device)

# %%
model
# Out:
# UsadModel(
#   (encoder): Encoder(
#     (linear1): Linear(in_features=24, out_features=20, bias=True)
#     (linear2): Linear(in_features=20, out_features=17, bias=True)
#     (linear3): Linear(in_features=17, out_features=12, bias=True)
#     (relu): ReLU(inplace=True)
#   )
#   (decoder1): Decoder(
#     (linear1): Linear(in_features=12, out_features=17, bias=True)
#     (linear2): Linear(in_features=17, out_features=20, bias=True)
#     (linear3): Linear(in_features=20, out_features=24, bias=True)
#     (relu): ReLU(inplace=True)
#     (sigmoid): Sigmoid()
#   )
#   (decoder2): Decoder(
#     (linear1): Linear(in_features=12, out_features=17, bias=True)
#     (linear2): Linear(in_features=17, out_features=20, bias=True)
#     (linear3): Linear(in_features=20, out_features=24, bias=True)
#     (relu): ReLU(inplace=True)
#     (sigmoid): Sigmoid()
#   )
# )

# %%
history = training(N_EPOCHS, model, train_loader, val_loader, test_loader, labels, window_size)
# Out:
# Epoch [0], val_loss1: 0.0514, val_loss2: 0.0529, ROC AUC: 0.8094, F1: 0.8097, Precision: 0.8767, Recall: 0.7523
# Epoch [1], val_loss1: 0.0372, val_loss2: -0.0019, ROC AUC: 0.7665, F1: 0.7518, Precision: 0.8355, Recall: 0.6833
# Epoch [2], val_loss1: 0.0420, val_loss2: -0.0169, ROC AUC: 0.6591, F1: 0.6620, Precision: 0.7653, Recall: 0.5833
# Epoch [3], val_loss1: 0.0406, val_loss2: -0.0227, ROC AUC: 0.6959, F1: 0.7100, Precision: 0.8025, Recall: 0.6366
# Epoch [4], val_loss1: 0.0542, val_loss2: -0.0378, ROC AUC: 0.2739, F1: 0.4156, Precision: 0.5415, Recall: 0.3372
# Epoch [5], val_loss1: 0.0469, val_loss2: -0.0335, ROC AUC: 0.8228, F1: 0.8315, Precision: 0.8912, Recall: 0.7793
# Epoch [6], val_loss1: 0.0468, val_loss2: -0.0357, ROC AUC: 0.8333, F1: 0.8434, Precision: 0.9004, Recall: 0.7933
# Epoch [7], val_loss1: 0.0468, val_loss2: -0.0375, ROC AUC: 0.8362, F1: 0.8449, Precision: 0.9006, Recall: 0.7957
# Epoch [8], val_loss1: 0.0471, val_loss2: -0.0391, ROC AUC: 0.8348, F1: 0.8436, Precision: 0.8996, Recall: 0.7941
# Epoch [9], val_loss1: 0.0472, val_loss2: -0.0401, ROC AUC: 0.8289, F1: 0.8370, Precision: 0.8953, Recall: 0.7859
# Epoch [10], val_loss1: 0.0479, val_loss2: -0.0415, ROC AUC: 0.8072, F1: 0.8127, Precision: 0.8781, Recall: 0.7564
# Epoch [11], val_loss1: 0.0494, val_loss2: -0.0434, ROC AUC: 0.7721, F1: 0.7780, Precision: 0.8539, Recall: 0.7145
# Epoch [12], val_loss1: 0.0492, val_loss2: -0.0436, ROC AUC: 0.7940, F1: 0.8062, Precision: 0.8751, Recall: 0.7473
# Epoch [13], val_loss1: 0.0493, val_loss2: -0.0442, ROC AUC: 0.8021, F1: 0.8120, Precision: 0.8787, Recall: 0.7547
# Epoch [14], val_loss1: 0.0508, val_loss2: -0.0459, ROC AUC: 0.7526, F1: 0.7708, Precision: 0.8483, Recall: 0.7063
# Epoch [15], val_loss1: 0.0511, val_loss2: -0.0465, ROC AUC: 0.7296, F1: 0.7509, Precision: 0.8345, Recall: 0.6825
# Epoch [16], val_loss1: 0.0506, val_loss2: -0.0464, ROC AUC: 0.7932, F1: 0.7993, Precision: 0.8690, Recall: 0.7400
# Epoch [17], val_loss1: 0.0504, val_loss2: -0.0464, ROC AUC: 0.7759, F1: 0.7863, Precision: 0.8598, Recall: 0.7244
# Epoch [18], val_loss1: 0.0516, val_loss2: -0.0476, ROC AUC: 0.8617, F1: 0.8647, Precision: 0.9141, Recall: 0.8203
# Epoch [19], val_loss1: 0.0506, val_loss2: -0.0469, ROC AUC: 0.8358, F1: 0.8338, Precision: 0.8932, Recall: 0.7818
# Epoch [20], val_loss1: 0.0495, val_loss2: -0.0461, ROC AUC: 0.8047, F1: 0.8097, Precision: 0.8767, Recall: 0.7523
# Epoch [21], val_loss1: 0.0511, val_loss2: -0.0477, ROC AUC: 0.7397, F1: 0.7532, Precision: 0.8352, Recall: 0.6858
# Epoch [22], val_loss1: 0.0500, val_loss2: -0.0468, ROC AUC: 0.8010, F1: 0.8083, Precision: 0.8756, Recall: 0.7506
# Epoch [23], val_loss1: 0.0499, val_loss2: -0.0469, ROC AUC: 0.7982, F1: 0.8069, Precision: 0.8745, Recall: 0.7490
# Epoch [24], val_loss1: 0.0500, val_loss2: -0.0471, ROC AUC: 0.7790, F1: 0.7916, Precision: 0.8634, Recall: 0.7309
# Epoch [25], val_loss1: 0.0496, val_loss2: -0.0468, ROC AUC: 0.7972, F1: 0.8055, Precision: 0.8734, Recall: 0.7473
# Epoch [26], val_loss1: 0.0501, val_loss2: -0.0475, ROC AUC: 0.8103, F1: 0.8164, Precision: 0.8812, Recall: 0.7605
# Epoch [27], val_loss1: 0.0523, val_loss2: -0.0497, ROC AUC: 0.8374, F1: 0.8458, Precision: 0.9016, Recall: 0.7966
# Epoch [28], val_loss1: 0.0504, val_loss2: -0.0479, ROC AUC: 0.7376, F1: 0.7465, Precision: 0.8310, Recall: 0.6776
# Epoch [29], val_loss1: 0.0500, val_loss2: -0.0477, ROC AUC: 0.7734, F1: 0.7863, Precision: 0.8598, Recall: 0.7244
# Epoch [30], val_loss1: 0.0502, val_loss2: -0.0479, ROC AUC: 0.7731, F1: 0.7911, Precision: 0.8632, Recall: 0.7301
# Epoch [31], val_loss1: 0.0504, val_loss2: -0.0482, ROC AUC: 0.7651, F1: 0.7791, Precision: 0.8542, Recall: 0.7162
# Epoch [32], val_loss1: 0.0509, val_loss2: -0.0487, ROC AUC: 0.7821, F1: 0.7970, Precision: 0.8692, Recall: 0.7358
# Epoch [33], val_loss1: 0.0518, val_loss2: -0.0498, ROC AUC: 0.7893, F1: 0.8113, Precision: 0.8770, Recall: 0.7547
# Epoch [34], val_loss1: 0.0521, val_loss2: -0.0501, ROC AUC: 0.8098, F1: 0.8234, Precision: 0.8865, Recall: 0.7687
# Epoch [35], val_loss1: 0.0524, val_loss2: -0.0504, ROC AUC: 0.8033, F1: 0.8188, Precision: 0.8825, Recall: 0.7637
# Epoch [36], val_loss1: 0.0525, val_loss2: -0.0507, ROC AUC: 0.8057, F1: 0.8208, Precision: 0.8859, Recall: 0.7646
# Epoch [37], val_loss1: 0.0525, val_loss2: -0.0507, ROC AUC: 0.8055, F1: 0.8197, Precision: 0.8834, Recall: 0.7646
# Epoch [38], val_loss1: 0.0533, val_loss2: -0.0516, ROC AUC: 0.8114, F1: 0.8230, Precision: 0.8856, Recall: 0.7687
# Epoch [39], val_loss1: 0.0539, val_loss2: -0.0522, ROC AUC: 0.8136, F1: 0.8253, Precision: 0.8876, Recall: 0.7711
# Epoch [40], val_loss1: 0.0535, val_loss2: -0.0519, ROC AUC: 0.8201, F1: 0.8295, Precision: 0.8908, Recall: 0.7760
# Epoch [41], val_loss1: 0.0545, val_loss2: -0.0529, ROC AUC: 0.8250, F1: 0.8319, Precision: 0.8920, Recall: 0.7793
# Epoch [42], val_loss1: 0.0554, val_loss2: -0.0539, ROC AUC: 0.8312, F1: 0.8384, Precision: 0.8964, Recall: 0.7875
# Epoch [43], val_loss1: 0.0549, val_loss2: -0.0535, ROC AUC: 0.8374, F1: 0.8436, Precision: 0.8996, Recall: 0.7941
# Epoch [44], val_loss1: 0.0541, val_loss2: -0.0526, ROC AUC: 0.8512, F1: 0.8573, Precision: 0.9098, Recall: 0.8105
# Epoch [45], val_loss1: 0.0554, val_loss2: -0.0541, ROC AUC: 0.8358, F1: 0.8379, Precision: 0.8963, Recall: 0.7867
# Epoch [46], val_loss1: 0.0552, val_loss2: -0.0539, ROC AUC: 0.8334, F1: 0.8357, Precision: 0.8943, Recall: 0.7842
# Epoch [47], val_loss1: 0.0560, val_loss2: -0.0547, ROC AUC: 0.8318, F1: 0.8333, Precision: 0.8931, Recall: 0.7810
# Epoch [48], val_loss1: 0.0541, val_loss2: -0.0529, ROC AUC: 0.8291, F1: 0.8324, Precision: 0.8921, Recall: 0.7801
# Epoch [49], val_loss1: 0.0557, val_loss2: -0.0545, ROC AUC: 0.8322, F1: 0.8338, Precision: 0.8932, Recall: 0.7818
# Epoch [50], val_loss1: 0.0523, val_loss2: -0.0510, ROC AUC: 0.8476, F1: 0.8518, Precision: 0.9057, Recall: 0.8039
# Epoch [51], val_loss1: 0.0509, val_loss2: -0.0497, ROC AUC: 0.8241, F1: 0.8338, Precision: 0.8932, Recall: 0.7818
# Epoch [52], val_loss1: 0.0525, val_loss2: -0.0514, ROC AUC: 0.8406, F1: 0.8504, Precision: 0.9047, Recall: 0.8023
# Epoch [53], val_loss1: 0.0510, val_loss2: -0.0499, ROC AUC: 0.8428, F1: 0.8518, Precision: 0.9057, Recall: 0.8039
# Epoch [54], val_loss1: 0.0529, val_loss2: -0.0518, ROC AUC: 0.8391, F1: 0.8467, Precision: 0.9025, Recall: 0.7974
# Epoch [55], val_loss1: 0.0524, val_loss2: -0.0513, ROC AUC: 0.8261, F1: 0.8357, Precision: 0.8943, Recall: 0.7842
# Epoch [56], val_loss1: 0.0544, val_loss2: -0.0534, ROC AUC: 0.8285, F1: 0.8384, Precision: 0.8964, Recall: 0.7875
# Epoch [57], val_loss1: 0.0530, val_loss2: -0.0520, ROC AUC: 0.8339, F1: 0.8421, Precision: 0.8993, Recall: 0.7916
# Epoch [58], val_loss1: 0.0544, val_loss2: -0.0534, ROC AUC: 0.8354, F1: 0.8431, Precision: 0.8995, Recall: 0.7933
# Epoch [59], val_loss1: 0.0537, val_loss2: -0.0527, ROC AUC: 0.8363, F1: 0.8431, Precision: 0.8995, Recall: 0.7933
# Epoch [60], val_loss1: 0.0538, val_loss2: -0.0528, ROC AUC: 0.8305, F1: 0.8398, Precision: 0.8974, Recall: 0.7892
# Epoch [61], val_loss1: 0.0550, val_loss2: -0.0541, ROC AUC: 0.8349, F1: 0.8426, Precision: 0.8994, Recall: 0.7925
# Epoch [62], val_loss1: 0.0559, val_loss2: -0.0550, ROC AUC: 0.8361, F1: 0.8408, Precision: 0.8976, Recall: 0.7908
# Epoch [63], val_loss1: 0.0560, val_loss2: -0.0551, ROC AUC: 0.8351, F1: 0.8370, Precision: 0.8953, Recall: 0.7859
# Epoch [64], val_loss1: 0.0574, val_loss2: -0.0565, ROC AUC: 0.8370, F1: 0.8393, Precision: 0.8973, Recall: 0.7884
# Epoch [65], val_loss1: 0.0563, val_loss2: -0.0554, ROC AUC: 0.8363, F1: 0.8376, Precision: 0.8954, Recall: 0.7867
# Epoch [66], val_loss1: 0.0542, val_loss2: -0.0534, ROC AUC: 0.8361, F1: 0.8444, Precision: 0.9006, Recall: 0.7949
# Epoch [67], val_loss1: 0.0557, val_loss2: -0.0549, ROC AUC: 0.8374, F1: 0.8419, Precision: 0.9032, Recall: 0.7884
# Epoch [68], val_loss1: 0.0546, val_loss2: -0.0538, ROC AUC: 0.8333, F1: 0.8365, Precision: 0.8952, Recall: 0.7851
# Epoch [69], val_loss1: 0.0593, val_loss2: -0.0585, ROC AUC: 0.8343, F1: 0.8355, Precision: 0.8950, Recall: 0.7834
# Epoch [70], val_loss1: 0.0556, val_loss2: -0.0548, ROC AUC: 0.8456, F1: 0.8537, Precision: 0.9068, Recall: 0.8064
# Epoch [71], val_loss1: 0.0550, val_loss2: -0.0543, ROC AUC: 0.8401, F1: 0.8453, Precision: 0.9015, Recall: 0.7957
# Epoch [72], val_loss1: 0.0556, val_loss2: -0.0549, ROC AUC: 0.8441, F1: 0.8491, Precision: 0.9037, Recall: 0.8007
# Epoch [73], val_loss1: 0.0537, val_loss2: -0.0530, ROC AUC: 0.8381, F1: 0.8444, Precision: 0.9006, Recall: 0.7949
# Epoch [74], val_loss1: 0.0529, val_loss2: -0.0522, ROC AUC: 0.8336, F1: 0.8405, Precision: 0.8991, Recall: 0.7892
# Epoch [75], val_loss1: 0.0558, val_loss2: -0.0551, ROC AUC: 0.8431, F1: 0.8464, Precision: 0.9040, Recall: 0.7957
# Epoch [76], val_loss1: 0.0570, val_loss2: -0.0563, ROC AUC: 0.8432, F1: 0.8431, Precision: 0.8995, Recall: 0.7933
# Epoch [77], val_loss1: 0.0578, val_loss2: -0.0570, ROC AUC: 0.8317, F1: 0.8384, Precision: 0.8964, Recall: 0.7875
# Epoch [78], val_loss1: 0.0529, val_loss2: -0.0521, ROC AUC: 0.8357, F1: 0.8453, Precision: 0.9015, Recall: 0.7957
# Epoch [79], val_loss1: 0.0525, val_loss2: -0.0519, ROC AUC: 0.8366, F1: 0.8462, Precision: 0.9024, Recall: 0.7966
# Epoch [80], val_loss1: 0.0540, val_loss2: -0.0534, ROC AUC: 0.8435, F1: 0.8504, Precision: 0.9047, Recall: 0.8023
# Epoch [81], val_loss1: 0.0549, val_loss2: -0.0543, ROC AUC: 0.8429, F1: 0.8482, Precision: 0.9028, Recall: 0.7998
# Epoch [82], val_loss1: 0.0569, val_loss2: -0.0563, ROC AUC: 0.8474, F1: 0.8514, Precision: 0.9049, Recall: 0.8039
# Epoch [83], val_loss1: 0.0539, val_loss2: -0.0533, ROC AUC: 0.8369, F1: 0.8379, Precision: 0.8963, Recall: 0.7867
# Epoch [84], val_loss1: 0.0567, val_loss2: -0.0561, ROC AUC: 0.8459, F1: 0.8453, Precision: 0.9015, Recall: 0.7957
